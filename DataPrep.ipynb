# %%
# Imports first
import csv
from math import sqrt
import geopandas as gpd
import pandas as pd
import shapely
from shapely.ops import nearest_points
import numpy as np
from scipy import ndimage
from scipy.spatial import cKDTree  
import pyproj

import matplotlib
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from matplotlib.colors import ListedColormap
from matplotlib.ticker import MaxNLocator

# %%
# Set notebook display options
pd.set_option('display.max_rows', 500)

# %%
# Do housekeeping between runs
objects = ['neighborhoods',
           'schools',
           'crimes_extract',
           'crimes_header',
           'crimes']

for thing in objects:
    try:
        del thing
    except NameError as e:
        print("Couldn't delete {0}".format(thing))
        print(e)
        continue

# %%
def distance_to_nearest(row, geom_union, df1, df2, geom1_col='geometry', geom2_col='geometry', src_column=None):
#def distance_to_nearest(row, dtn_args):
     """Find the nearest point and return the corresponding value from specified column."""
     # Find the geometry that is closest
     nearest = df2[geom2_col] == nearest_points(row[geom1_col], geom_union)[1]
     print(row)
     print(nearest)
     # Get the corresponding value from df2 (matching is based on the geometry)
     nearest_id = df2[nearest][src_column].get_values()[0]
     start_point: shapely.geometry.Point = row['geometry']
     end_point_series: pd.Series = df2[nearest]['geometry']
     end_point: shapely.geometry.Point = end_point_series.iloc[0]
     dist_to_point = start_point.distance(end_point)
     return nearest_id, dist_to_point

# %%
# Define utility functions
def nearest(row, geom_union, df1, df2, geom1_col='geometry', geom2_col='geometry', src_column=None):
    """Find the nearest point and return the corresponding value from specified column."""
    # Find the geometry that is closest
    nearest = df2[geom2_col] == nearest_points(row[geom1_col], geom_union)[1]
    #nearest = df2[geom2_col] == nearest_points(df1, df2)[1]
    # Get the corresponding value from df2 (matching is based on the geometry)
    value = df2[nearest][src_column].get_values()[0]
    return value

# %%
def geod2utm(row):
    '''   Convert geodetic coordinates to UTM   '''
    #if zn == None :
    #    zn = lon2zone (lon)
    zn = '16T'
    datum = 'WGS84'
    lat = row['lat']
    lon = row['lon']
        
    p = pyproj.Proj(proj='utm', zone=zn, ellps=datum)
    
    X, Y = p(lon, lat)
    
    #   Return Y, X, Z
    # return Y, X, elev
    return pd.Series({'UTMx': X, 'UTMy': Y})

# %%
def make_utm_points(row):
    UTMx = row['UTMx']
    UTMy = row['UTMy']
    UTMPoint = shapely.geometry.Point(UTMx, UTMy)
    return UTMPoint

# %%
# Fix column type in neighborhoods dataset
neighborhoods = pd.read_pickle("neighborhoods.pkl")

# %%
neighborhoods['area_numbe'] = neighborhoods['area_numbe'].astype('float64')

# %%
neighborhoods.to_pickle('neighborhoods-transformed.pkl')

# %%
# Enhance school data with UTM coordinates and associated shapely Points
schools = pd.read_pickle("schools.pkl")

# %%
schools.rename(columns={'X': 'lon', 'Y': 'lat'}, inplace=True)
schools.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 688 entries, 4610 to 4210
# Data columns (total 12 columns):
# geometry     688 non-null object
# SCHOOL_NM    688 non-null object
# SCHOOL_ID    688 non-null int64
# SCH_ADDR     688 non-null object
# GRADE_CAT    688 non-null object
# SCH_TYPE     688 non-null object
# lon          688 non-null float64
# lat          688 non-null float64
# UNIT_ID      688 non-null int64
# UTMx         688 non-null float64
# UTMy         688 non-null float64
# UTMPoint     688 non-null object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 69.9+ KB

# %%
schools['UTMx'] = np.zeros(len(schools))
schools['UTMy'] = np.zeros(len(schools))
schools.loc[:, ('UTMx', 'UTMy')] = schools.apply(geod2utm, axis=1)
schools['UTMPoint'] = schools.apply(make_utm_points, axis=1)
schools.head()
# Out:
#                                         geometry SCHOOL_NM  SCHOOL_ID  \
# UNIT_ID
# 4610        POINT (-87.5748539059 41.7483660139)      MANN     610052
# 5180     POINT (-87.57284397069999 41.768650177)   OKEEFFE     610103
# 5300         POINT (-87.5829920307 41.768594283)  PARKSIDE     610116
# 5440     POINT (-87.60800008530001 41.740365734)     PIRIE     610130
# 5610     POINT (-87.60015764629999 41.764223475)    REVERE     610146
#
#                    SCH_ADDR GRADE_CAT           SCH_TYPE        lon  \
# UNIT_ID
# 4610      8050 S CHAPPEL AV        ES  Elementary School -87.574854
# 5180      6940 S MERRILL AV        ES  Elementary School -87.572844
# 5300     6938 S EAST END AV        ES  Elementary School -87.582992
# 5440          650 E 85TH ST        ES  Elementary School -87.608000
# 5610         1010 E 72ND ST        ES  Elementary School -87.600158
#
#                lat  UNIT_ID           UTMx          UTMy  \
# UNIT_ID
# 4610     41.748366     4610  452204.771983  4.621998e+06
# 5180     41.768650     5180  452386.881166  4.624249e+06
# 5300     41.768594     5300  451543.358669  4.624248e+06
# 5440     41.740366     5440  449442.603124  4.621129e+06
# 5610     41.764223     5610  450113.209645  4.623773e+06
#
#                                             UTMPoint
# UNIT_ID
# 4610     POINT (452204.7719826915 4621997.860158128)
# 5180      POINT (452386.881166386 4624248.790945017)
# 5300      POINT (451543.3586693273 4624248.25277694)
# 5440     POINT (449442.6031235668 4621128.574748854)
# 5610     POINT (450113.2096448886 4623772.796898597)

# %%
schools.to_pickle('schools-transformed.pkl')

# %%
# Enhance crimes data with community name from the neighborhoods dataset and UTM coordinates/Points
crimes_header = ['ID', 'case number', 'date', 'block', 'iucr', 'primary type', 'desc', 'locdesc',
                 'arrest', 'domestic', 'beat', 'district', 'ward', 'community area', 'fbi code',
                 'x coord', 'y coord', 'year', 'updated on', 'lat', 'lon', 'location'
                ]
crimes = pd.read_csv("parallel/xaa", names=crimes_header, header=None)
crimes.dropna(subset=['lat', 'lon'], inplace=True)

# %%
crimes = (crimes.merge(neighborhoods[['community', 'area_numbe']], left_on='community area', right_on='area_numbe'))
del crimes['area_numbe']

# %%
crimes['UTMx'] = np.zeros(len(crimes))
crimes['UTMy'] = np.zeros(len(crimes))
crimes.loc[:, ('UTMx', 'UTMy')] = crimes.apply(geod2utm, axis=1)
crimes.head()
# Out:
#         ID case number                    date                 block  iucr  \
# 0  8265244    HT498458  09/15/2011 08:00:00 AM    040XX N MENARD AVE  0620
# 1  7357772    HS159408  07/01/2001 10:00:00 AM  056XX W CORNELIA AVE  0840
# 2  7609828    HS413731  07/13/2010 12:00:00 PM      041XX N LONG AVE  0820
# 3  7610439    HS413034  07/16/2010 03:00:00 AM     056XX W SCHOOL ST  0486
# 4  7610466    HS414753  07/17/2010 12:25:00 AM    032XX N CICERO AVE  1506
#
#    primary type                           desc        locdesc  arrest  \
# 0      BURGLARY                 UNLAWFUL ENTRY      RESIDENCE    True
# 1         THEFT  FINANCIAL ID THEFT: OVER $300      RESIDENCE   False
# 2         THEFT                 $500 AND UNDER  PARK PROPERTY   False
# 3       BATTERY        DOMESTIC BATTERY SIMPLE      RESIDENCE   False
# 4  PROSTITUTION          SOLICIT ON PUBLIC WAY          ALLEY    True
#
#    domestic      ...         x coord    y coord  year              updated on  \
# 0     False      ...       1136960.0  1926315.0  2011  02/12/2018 03:46:59 PM
# 1     False      ...       1138173.0  1922746.0  2001  02/18/2010 01:12:55 AM
# 2     False      ...       1139616.0  1926816.0  2010  02/04/2016 06:33:39 AM
# 3      True      ...       1138176.0  1921375.0  2010  02/04/2016 06:33:39 AM
# 4     False      ...       1143808.0  1920986.0  2010  02/04/2016 06:33:39 AM
#
#          lat        lon                       location     community  \
# 0  41.953965 -87.771918   (41.95396528, -87.771918163)  PORTAGE PARK
# 1  41.944150 -87.767546    (41.9441497, -87.767545572)  PORTAGE PARK
# 2  41.955292 -87.762142   (41.95529191, -87.762141971)  PORTAGE PARK
# 3  41.940387 -87.767568  (41.940387482, -87.767567805)  PORTAGE PARK
# 4  41.939216 -87.746878  (41.939216164, -87.746877814)  PORTAGE PARK
#
#             UTMx          UTMy
# 0  436025.308686  4.644953e+06
# 1  436377.940882  4.643860e+06
# 2  436836.850742  4.645093e+06
# 3  436372.357517  4.643442e+06
# 4  438086.334871  4.643297e+06
#
# [5 rows x 25 columns]

# %%
crimes['UTMPoint'] = crimes.apply(make_utm_points, axis=1)

# %%
crimes.head()
# Out:
#         ID case number                    date                 block  iucr  \
# 0  8265244    HT498458  09/15/2011 08:00:00 AM    040XX N MENARD AVE  0620
# 1  7357772    HS159408  07/01/2001 10:00:00 AM  056XX W CORNELIA AVE  0840
# 2  7609828    HS413731  07/13/2010 12:00:00 PM      041XX N LONG AVE  0820
# 3  7610439    HS413034  07/16/2010 03:00:00 AM     056XX W SCHOOL ST  0486
# 4  7610466    HS414753  07/17/2010 12:25:00 AM    032XX N CICERO AVE  1506
#
#    primary type                           desc        locdesc  arrest  \
# 0      BURGLARY                 UNLAWFUL ENTRY      RESIDENCE    True
# 1         THEFT  FINANCIAL ID THEFT: OVER $300      RESIDENCE   False
# 2         THEFT                 $500 AND UNDER  PARK PROPERTY   False
# 3       BATTERY        DOMESTIC BATTERY SIMPLE      RESIDENCE   False
# 4  PROSTITUTION          SOLICIT ON PUBLIC WAY          ALLEY    True
#
#    domestic                     ...                        y coord  year  \
# 0     False                     ...                      1926315.0  2011
# 1     False                     ...                      1922746.0  2001
# 2     False                     ...                      1926816.0  2010
# 3      True                     ...                      1921375.0  2010
# 4     False                     ...                      1920986.0  2010
#
#                updated on        lat        lon  \
# 0  02/12/2018 03:46:59 PM  41.953965 -87.771918
# 1  02/18/2010 01:12:55 AM  41.944150 -87.767546
# 2  02/04/2016 06:33:39 AM  41.955292 -87.762142
# 3  02/04/2016 06:33:39 AM  41.940387 -87.767568
# 4  02/04/2016 06:33:39 AM  41.939216 -87.746878
#
#                         location     community           UTMx          UTMy  \
# 0   (41.95396528, -87.771918163)  PORTAGE PARK  436025.308686  4.644953e+06
# 1    (41.9441497, -87.767545572)  PORTAGE PARK  436377.940882  4.643860e+06
# 2   (41.95529191, -87.762141971)  PORTAGE PARK  436836.850742  4.645093e+06
# 3  (41.940387482, -87.767567805)  PORTAGE PARK  436372.357517  4.643442e+06
# 4  (41.939216164, -87.746877814)  PORTAGE PARK  438086.334871  4.643297e+06
#
#                                      UTMPoint
# 0  POINT (436025.3086861699 4644953.17679981)
# 1  POINT (436377.940881997 4643860.108357577)
# 2  POINT (436836.8507415869 4645093.21940705)
# 3  POINT (436372.3575166143 4643442.41025281)
# 4  POINT (438086.3348712226 4643297.20981963)
#
# [5 rows x 26 columns]

# %%
# Create a small extract of data to test performance of algorithms
crimes_extract = crimes.iloc[0:100]

# %%
schools.set_index("UNIT_ID")
schools['UNIT_ID'] = schools.index
schools.head()
# Out:
#                                         geometry SCHOOL_NM  SCHOOL_ID  \
# UNIT_ID
# 4610        POINT (-87.5748539059 41.7483660139)      MANN     610052
# 5180     POINT (-87.57284397069999 41.768650177)   OKEEFFE     610103
# 5300         POINT (-87.5829920307 41.768594283)  PARKSIDE     610116
# 5440     POINT (-87.60800008530001 41.740365734)     PIRIE     610130
# 5610     POINT (-87.60015764629999 41.764223475)    REVERE     610146
#
#                    SCH_ADDR GRADE_CAT           SCH_TYPE        lon  \
# UNIT_ID
# 4610      8050 S CHAPPEL AV        ES  Elementary School -87.574854
# 5180      6940 S MERRILL AV        ES  Elementary School -87.572844
# 5300     6938 S EAST END AV        ES  Elementary School -87.582992
# 5440          650 E 85TH ST        ES  Elementary School -87.608000
# 5610         1010 E 72ND ST        ES  Elementary School -87.600158
#
#                lat  UNIT_ID           UTMx          UTMy  \
# UNIT_ID
# 4610     41.748366     4610  452204.771983  4.621998e+06
# 5180     41.768650     5180  452386.881166  4.624249e+06
# 5300     41.768594     5300  451543.358669  4.624248e+06
# 5440     41.740366     5440  449442.603124  4.621129e+06
# 5610     41.764223     5610  450113.209645  4.623773e+06
#
#                                             UTMPoint
# UNIT_ID
# 4610     POINT (452204.7719826915 4621997.860158128)
# 5180      POINT (452386.881166386 4624248.790945017)
# 5300      POINT (451543.3586693273 4624248.25277694)
# 5440     POINT (449442.6031235668 4621128.574748854)
# 5610     POINT (450113.2096448886 4623772.796898597)

# %%
#schools2 = schools
#len(schools2)
#df = df[~df['A'].apply(tuple).duplicated()]
#schools3 = schools2[~schools2[]]
#schools2[schools2.groupby(['UNIT_ID', 'SCHOOL_NM', 'SCHOOL_ID', 'UTMx', 'UTMy']).count() > 1]
#schools2.drop_duplicates(subset=['UNIT_ID', 'SCHOOL_ID']).count()
#schools2[schools2.duplicated(subset=['UTMx', 'UTMy'])].sort_values('SCHOOL_ID')
#len(schools2)
# Out:
#                                              geometry  \
# UNIT_ID
# 6655             POINT (-87.6353490959 41.7707452934)
# 7020         POINT (-87.76321129540001 41.8851821631)
# 4370             POINT (-87.7080245074 41.8584605337)
# 8047              POINT (-87.618372173 41.8363986498)
# 7810         POINT (-87.72133536530001 41.8583288116)
# 5870         POINT (-87.7305482714 41.85685112239999)
# 1933         POINT (-87.66453430780001 41.8953088467)
# 1962         POINT (-87.65225497829999 41.7459401482)
# 1963         POINT (-87.65225497829999 41.7459401482)
# 4140         POINT (-87.62448455090001 41.8045795662)
# 3061         POINT (-87.59817741260001 41.7780905854)
# 3344         POINT (-87.73036027969999 41.8078949448)
# 3345         POINT (-87.73036027969999 41.8078949448)
# 7030         POINT (-87.63494065379999 41.7814585083)
# 5811             POINT (-87.6838982543 41.8492209837)
# 8078             POINT (-87.6782288854 41.8788357283)
# 7670              POINT (-87.573183031 41.7372026166)
# 7970             POINT (-87.6376075668 41.6899107968)
# 1510         POINT (-87.61976542299999 41.8239077905)
# 1590             POINT (-87.6429299556 41.8075155767)
# 1510         POINT (-87.61976542299999 41.8239077905)
# 2060         POINT (-87.67373229819999 41.9028958229)
# 2200             POINT (-87.6474867189 41.7848939801)
# 2400         POINT (-87.67071801590001 41.8829641939)
# 2530             POINT (-87.6686140092 41.9123309686)
# 2640         POINT (-87.65927003360001 41.8935772887)
# 3320         POINT (-87.59037654629999 41.7677278532)
# 3640          POINT (-87.59845412129999 41.811334985)
# 4080             POINT (-87.5681880799 41.7332283153)
# 4170         POINT (-87.67577244290001 41.9392335448)
# 4430         POINT (-87.71312754590001 41.8629853139)
# 4600         POINT (-87.75816603370001 41.9205389482)
# 4640         POINT (-87.70805527799999 41.8797415311)
# 4870             POINT (-87.6969074304 41.9125934984)
# 5150             POINT (-87.6455364956 41.9077735042)
# 5220             POINT (-87.6653886853 41.8917731278)
# 5270             POINT (-87.6353490959 41.7707452934)
# 5520         POINT (-87.68379639600001 41.9185138187)
# 5790             POINT (-87.6805222693 41.9356763366)
# 6210         POINT (-87.73052903690001 41.8840823974)
# 6290         POINT (-87.70962733360001 41.9711464431)
# 6460             POINT (-87.6778839441 41.9070235838)
# 6670          POINT (-87.77650757469999 41.942200085)
# 6730         POINT (-87.69931227629999 41.8829760971)
# 6880         POINT (-87.63726903700001 41.7727761389)
# 6940         POINT (-87.70317594059999 41.8618505522)
# 7220         POINT (-87.57964641059999 41.7579528143)
# 7310         POINT (-87.68865069030001 41.8788540071)
# 7360             POINT (-87.5577331089 41.7337613058)
# 7380         POINT (-87.57960707149999 41.7561842082)
# 7510             POINT (-87.6929631741 41.9067225919)
# 7520         POINT (-87.72036100530001 41.9521145275)
# 7540             POINT (-87.5577331089 41.7337613058)
# 7550             POINT (-87.5577331089 41.7337613058)
# 7720             POINT (-87.6285899176 41.8440256847)
# 7930             POINT (-87.6991215382 41.8481236752)
# 7570             POINT (-87.6371172991 41.7697814896)
# 7650             POINT (-87.6652639441 41.9890979437)
# 7660         POINT (-87.68325366889999 41.8774737697)
# 7270         POINT (-87.62448455090001 41.8045795662)
# 7600         POINT (-87.73419374389999 41.8359816175)
# 7680         POINT (-87.73419374389999 41.8359816175)
# 7630         POINT (-87.73419374389999 41.8359816175)
# 7140             POINT (-87.6652639441 41.9890979437)
# 7980             POINT (-87.6868691599 41.9026154396)
# 1045             POINT (-87.7020127559 41.8641812675)
# 1065         POINT (-87.76321129540001 41.8851821631)
# 5850             POINT (-87.7263300086 41.8669585438)
# 1055     POINT (-87.65926638160001 41.86327022010001)
#
#                                     SCHOOL_NM  SCHOOL_ID  \
# UNIT_ID
# 6655                                  AMANDLA     400012
# 7020                    AUSTIN BUS & ENTRP HS     400018
# 4370                                 CATALYST     400020
# 8047                          CHICAGO ARTS HS     400022
# 7810                      KIPP ASCEND CHARTER     400044
# 5870                           LEGACY CHARTER     400049
# 1933                           NOBLE - GOLDER     400053
# 1962     PERSPECTIVES - CALUMET TECHNOLOGY HS     400062
# 1963             PERSPECTIVES - MIDDLE SCHOOL     400067
# 4140                   SHABAZZ CHTR - DUSABLE     400073
# 3061             U of C CHARTER HS - WOODLAWN     400077
# 3344                            UNO - ZIZUMBO     400079
# 3345                             UNO - TORRES     400080
# 7030               URBAN PREP MENS CHARTER HS     400086
# 5811                        UNO - PAZ PRIMARY     400090
# 8078                            NOBLE - BULLS     400097
# 7670                    CHICAGO VOCATIONAL AA     609675
# 7970                                FENGER AA     609706
# 1510                              PHILLIPS HS     609727
# 1590                                TILDEN HS     609735
# 1510                              PHILLIPS AA     609743
# 2060                                 ANDERSEN     609776
# 2200                                NICHOLSON     609793
# 2400                                 BROWN, W     609812
# 2530                                     BURR     609828
# 2640                                CARPENTER     609838
# 3320                                    FERMI     609916
# 3640                                    ARIEL     609951
# 4080                                    HOYNE     610002
# 4170                                     JAHN     610010
# 4430                                 LAWNDALE     610034
# 4600                                NORTHWEST     610051
# 4640                                  FARADAY     610055
# 4870                                     MOOS     610076
# 5150                                    OGDEN     610101
# 5220                                     OTIS     610107
# 5270                                   PARKER     610112
# 5520                                  PULASKI     610138
# 5790                                SCHNEIDER     610164
# 6210                                   TILTON     610202
# 6290                              ALBANY PARK     610212
# 6460                                 PRITZKER     610229
# 6670                       CHICAGO ACADEMY ES     610248
# 6730                                   CATHER     610251
# 6880                                 BANNEKER     610265
# 6940                                  JOHNSON     610274
# 7220                  SCHOOL OF TECHNOLOGY HS     610296
# 7310                      PHOENIX MILITARY HS     610304
# 7360                     CHICAGO DISCOVERY HS     610309
# 7380                       SCHOOL OF ENTRP HS     610311
# 7510                                DE DUPREY     610320
# 7520                          MARSHALL MIDDLE     610321
# 7540                        NEW MILLENNIUM HS     610323
# 7550                        GLOBAL VISIONS HS     610324
# 7720                          WILLIAMS MIDDLE     610336
# 7930                                  SPRY HS     610357
# 7570                               ROBESON AA     610374
# 7650                                  SENN AA     610377
# 7660                                 CRANE AA     610378
# 7270                           BRONZEVILLE HS     610381
# 7600                        SOCIAL JUSTICE HS     610383
# 7680                           INFINITY HS HS     610384
# 7630                   MULTI-CULTURAL ARTS HS     610385
# 7140                     RICKOVER MILITARY HS     610390
# 7980                              CLEMENTE AA     610401
# 1045       COLLINS ACADEMY HIGH SCHOOL (AUSL)     610499
# 1065             AUSTIN POLYTECHNICAL ACADEMY     610501
# 5850                    FRAZIER INTERNATIONAL     610503
# 1055                             AIR FORCE HS     610513
#
#                       SCH_ADDR GRADE_CAT           SCH_TYPE        lon  \
# UNIT_ID
# 6655         6800 S STEWART AV        HS            Charter -87.635349
# 7020             231 N PINE AV        HS           Contract -87.763211
# 4370       1616 S SPAULDING AV        ES            Charter -87.708025
# 8047        3200 S. CALUMET AV        HS           Contract -87.618372
# 7810           1616 S AVERS AV        MS            Charter -87.721335
# 5870            4217 W 18TH ST        ES            Charter -87.730548
# 1933       1454 W. SUPERIOR ST        HS            Charter -87.664534
# 1962             8131 S MAY ST        HS            Charter -87.652255
# 1963             8131 S MAY ST        MS            Charter -87.652255
# 4140          4934 S WABASH AV        HS            Charter -87.624485
# 3061     6420 S. UNIVERSITY AV        HS            Charter -87.598177
# 3344           4248 W. 47TH ST        ES            Charter -87.730360
# 3345           4248 W. 47TH ST        ES            Charter -87.730360
# 7030         6201 S STEWART AV        HS            Charter -87.634941
# 5811            2317 W 23RD PL        ES            Charter -87.683898
# 8078           2040 W ADAMS ST        HS            Charter -87.678229
# 7670            2100 E 87TH ST        HS        High School -87.573183
# 7970        11220 S WALLACE ST        HS        High School -87.637608
# 1510         244 E PERSHING RD        HS        High School -87.619765
# 1590           4747 S UNION AV        HS        High School -87.642930
# 1510         244 E PERSHING RD        HS        High School -87.619765
# 2060          1148 N HONORE ST        ES  Elementary School -87.673732
# 2200          6006 S PEORIA ST        ES  Elementary School -87.647487
# 2400         54 N HERMITAGE AV        ES  Elementary School -87.670718
# 2530        1621 W WABANSIA AV        ES  Elementary School -87.668614
# 2640            1250 W ERIE ST        ES  Elementary School -87.659270
# 3320            1415 E 70TH ST        ES  Elementary School -87.590377
# 3640            1119 E 46TH ST        ES  Elementary School -87.598454
# 4080         8905 S CRANDON AV        ES  Elementary School -87.568188
# 4170         3149 N WOLCOTT AV        ES  Elementary School -87.675772
# 4430         3500 W DOUGLAS BL        ES  Elementary School -87.713128
# 4600          5252 W PALMER ST        MS  Elementary School -87.758166
# 4640          3250 W MONROE ST        ES  Elementary School -87.708055
# 4870      1711 N CALIFORNIA AV        ES  Elementary School -87.696907
# 5150          1443 N. OGDEN AV        ES  Elementary School -87.645536
# 5220           525 N ARMOUR ST        ES  Elementary School -87.665389
# 5270         6800 S STEWART AV        ES  Elementary School -87.635349
# 5520          2230 W MCLEAN AV        ES  Elementary School -87.683796
# 5790           2957 N HOYNE AV        ES  Elementary School -87.680522
# 6210           223 N KEELER AV        ES  Elementary School -87.730529
# 6290          4929 N SAWYER AV        MS  Elementary School -87.709627
# 6460        2009 W SCHILLER ST        ES  Elementary School -87.677884
# 6670          3400 N AUSTIN AV        ES  Elementary School -87.776508
# 6730      2908 W WASHINGTON BL        ES  Elementary School -87.699312
# 6880          6656 S NORMAL BL        ES  Elementary School -87.637269
# 6940          1420 S ALBANY AV        ES  Elementary School -87.703176
# 7220       7529 S CONSTANCE AV        HS        High School -87.579646
# 7310         145 S CAMPBELL AV        HS        High School -87.688651
# 7360            2710 E 89TH ST        HS        High School -87.557733
# 7380       7627 S CONSTANCE AV        HS        High School -87.579607
# 7510          2620 W HIRSCH ST        ES  Elementary School -87.692963
# 7520        3900 N LAWNDALE AV        MS  Elementary School -87.720361
# 7540            2710 E 89TH ST        HS        High School -87.557733
# 7550            2710 E 89TH ST        HS        High School -87.557733
# 7720        2710 S DEARBORN ST        MS  Elementary School -87.628590
# 7930        2400 S MARSHALL BL        HS        High School -87.699122
# 7570          6835 S NORMAL BL        HS        High School -87.637117
# 7650        5900 N GLENWOOD AV        HS        High School -87.665264
# 7660         2245 W JACKSON BL        HS        High School -87.683254
# 7270          4934 S WABASH AV        HS        High School -87.624485
# 7600         3120 S KOSTNER AV        HS        High School -87.734194
# 7680         3120 S KOSTNER AV        HS        High School -87.734194
# 7630         3120 S KOSTNER AV        HS        High School -87.734194
# 7140        5900 N GLENWOOD AV        HS        High School -87.665264
# 7980         1147 N WESTERN AV        HS        High School -87.686869
# 1045      1313 S SACRAMENTO DR        HS        High School -87.702013
# 1065             231 N PINE AV        HS        High School -87.763211
# 5850        4027 W GRENSHAW ST        ES  Elementary School -87.726330
# 1055            1301 W 14TH ST        HS        High School -87.659266
#
#                lat  UNIT_ID           UTMx          UTMy  \
# UNIT_ID
# 6655     41.770745     6655  447193.332704  4.624518e+06
# 7020     41.885182     7020  436678.950463  4.637310e+06
# 4370     41.858461     4370  441233.165597  4.634304e+06
# 8047     41.836399     8047  448656.807730  4.631797e+06
# 7810     41.858329     7810  440128.220031  4.634298e+06
# 5870     41.856851     5870  439362.136215  4.634141e+06
# 1933     41.895309     1933  444874.596220  4.638366e+06
# 1962     41.745940     1962  445767.322694  4.621774e+06
# 1963     41.745940     1963  445767.322694  4.621774e+06
# 4140     41.804580     4140  448123.621404  4.628268e+06
# 3061     41.778091     3061  450288.520892  4.625311e+06
# 3344     41.807895     3344  439331.526779  4.628705e+06
# 3345     41.807895     3345  439331.526779  4.628705e+06
# 7030     41.781459     7030  447236.062194  4.625707e+06
# 5811     41.849221     5811  443227.512213  4.633262e+06
# 8078     41.878836     8078  443724.122482  4.636546e+06
# 7670     41.737203     7670  452335.439140  4.620758e+06
# 7970     41.689911     7970  446939.139874  4.615545e+06
# 1510     41.823908     1510  448531.121247  4.630411e+06
# 1590     41.807516     1590  446593.779697  4.628605e+06
# 1510     41.823908     1510  448531.121247  4.630411e+06
# 2060     41.902896     2060  444118.202701  4.639214e+06
# 2200     41.784894     2200  446196.344064  4.626096e+06
# 2400     41.882964     2400  444350.920533  4.636999e+06
# 2530     41.912331     2530  444550.899804  4.640259e+06
# 2640     41.893577     2640  445309.810750  4.638170e+06
# 3320     41.767728     3320  450928.915959  4.624156e+06
# 3640     41.811335     3640  450291.219557  4.629002e+06
# 4080     41.733228     4080  452747.896220  4.620314e+06
# 4170     41.939234     4170  443980.778062  4.643250e+06
# 4430     41.862985     4430  440813.778020  4.634810e+06
# 4600     41.920539     4600  437132.236202  4.641232e+06
# 4640     41.879742     4640  441250.100822  4.636667e+06
# 4870     41.912593     4870  442204.711006  4.640306e+06
# 5150     41.907774     5150  446460.951258  4.639738e+06
# 5220     41.891773     5220  444800.677973  4.637974e+06
# 5270     41.770745     5270  447193.332704  4.624518e+06
# 5520     41.918514     5520  443297.269871  4.640955e+06
# 5790     41.935676     5790  443583.896492  4.642858e+06
# 6210     41.884082     6210  439389.463617  4.637164e+06
# 6290     41.971146     6290  441203.648688  4.646816e+06
# 6460     41.907024     6460  443777.470062  4.639675e+06
# 6670     41.942200     6670  435633.112210  4.643650e+06
# 6730     41.882976     6730  441978.469562  4.637020e+06
# 6880     41.772776     6880  447035.427874  4.624745e+06
# 6940     41.861851     6940  441638.687038  4.634677e+06
# 7220     41.757953     7220  451813.476839  4.623065e+06
# 7310     41.878854     7310  442859.387451  4.636555e+06
# 7360     41.733761     7360  453617.747402  4.620367e+06
# 7380     41.756184     7380  451815.424224  4.622869e+06
# 7510     41.906723     7510  442526.548032  4.639652e+06
# 7520     41.952115     7520  440296.537935  4.644710e+06
# 7540     41.733761     7540  453617.747402  4.620367e+06
# 7550     41.733761     7550  453617.747402  4.620367e+06
# 7720     41.844026     7720  447814.626084  4.632650e+06
# 7930     41.848124     7930  441962.782036  4.633150e+06
# 7570     41.769781     7570  447045.576167  4.624412e+06
# 7650     41.989098     7650  444894.886910  4.648780e+06
# 7660     41.877474     7660  443305.986299  4.636398e+06
# 7270     41.804580     7270  448123.621404  4.628268e+06
# 7600     41.835982     7600  439039.739199  4.631826e+06
# 7680     41.835982     7680  439039.739199  4.631826e+06
# 7630     41.835982     7630  439039.739199  4.631826e+06
# 7140     41.989098     7140  444894.886910  4.648780e+06
# 7980     41.902615     7980  443028.328865  4.639192e+06
# 1045     41.864181     1045  441737.344127  4.634935e+06
# 1065     41.885182     1065  436678.950463  4.637310e+06
# 5850     41.866959     5850  439721.761752  4.635260e+06
# 1055     41.863270     1055  445284.266323  4.634806e+06
#
#                                             UTMPoint
# UNIT_ID
# 6655     POINT (447193.3327041139 4624517.890699782)
# 7020     POINT (436678.9504628467 4637309.836276419)
# 4370     POINT (441233.1655973321 4634303.755934255)
# 8047     POINT (448656.8077300153 4631796.821226656)
# 7810     POINT (440128.2200308657 4634298.327671785)
# 5870     POINT (439362.1362152169 4634140.729628502)
# 1933      POINT (444874.5962195973 4638366.07121895)
# 1962     POINT (445767.3226936422 4621774.417733593)
# 1963     POINT (445767.3226936422 4621774.417733593)
# 4140     POINT (448123.6214036231 4628267.743629881)
# 3061     POINT (450288.5208919291 4625311.247757245)
# 3344     POINT (439331.5267788519 4628705.158174811)
# 3345     POINT (439331.5267788519 4628705.158174811)
# 7030     POINT (447236.0621941395 4625707.077792206)
# 5811      POINT (443227.5122132096 4633261.68515774)
# 8078       POINT (443724.1224816345 4636545.9912537)
# 7670     POINT (452335.4391400405 4620757.522713686)
# 7970      POINT (446939.139873704 4615544.676748256)
# 1510     POINT (448531.1212473041 4630410.841202665)
# 1590     POINT (446593.7796974278 4628605.014284009)
# 1510     POINT (448531.1212473041 4630410.841202665)
# 2060     POINT (444118.2027007077 4639214.386738423)
# 2200     POINT (446196.3440644828 4626096.277183043)
# 2400     POINT (444350.9205329206 4636999.466323709)
# 2530     POINT (444550.8998038461 4640258.629570856)
# 2640     POINT (445309.8107496799 4638170.451520003)
# 3320     POINT (450928.9159587382 4624156.244028927)
# 3640      POINT (450291.219557339 4629002.385832878)
# 4080     POINT (452747.8962201036 4620313.524190674)
# 4170     POINT (443980.7780623997 4643250.228380322)
# 4430     POINT (440813.7780202755 4634809.634637848)
# 4600     POINT (437132.2362023372 4641231.720161318)
# 4640     POINT (441250.1008224849 4636666.547744862)
# 4870     POINT (442204.7110056735 4640306.456378425)
# 5150     POINT (446460.9512582251 4639737.961944163)
# 5220     POINT (444800.6779727979 4637974.058083979)
# 5270     POINT (447193.3327041139 4624517.890699782)
# 5520     POINT (443297.2698709437 4640955.026336959)
# 5790     POINT (443583.8964922273 4642858.391768791)
# 6210     POINT (439389.4636170255 4637164.132151863)
# 6290     POINT (441203.6486875463 4646816.160446844)
# 6460     POINT (443777.4700621322 4639675.396017756)
# 6670     POINT (435633.1122095861 4643650.335781304)
# 6730     POINT (441978.4695616806 4637019.725343959)
# 6880     POINT (447035.4278737203 4624744.546353295)
# 6940     POINT (441638.6870378573 4634676.832456944)
# 7220     POINT (451813.4768388519 4623064.905180683)
# 7310     POINT (442859.3874505504 4636554.906880246)
# 7360     POINT (453617.7474016545 4620367.012159662)
# 7380     POINT (451815.4242244918 4622868.524017614)
# 7510     POINT (442526.5480316527 4639651.971077606)
# 7520     POINT (440296.5379346409 4644710.487164973)
# 7540     POINT (453617.7474016545 4620367.012159662)
# 7550     POINT (453617.7474016545 4620367.012159662)
# 7720     POINT (447814.6260841662 4632649.782207773)
# 7930     POINT (441962.7820355565 4633150.030818208)
# 7570      POINT (447045.576167007 4624411.971370929)
# 7650     POINT (444894.8869103333 4648779.807261443)
# 7660     POINT (443305.9862992575 4636398.083581113)
# 7270     POINT (448123.6214036231 4628267.743629881)
# 7600      POINT (439039.7391990065 4631826.23431028)
# 7680      POINT (439039.7391990065 4631826.23431028)
# 7630      POINT (439039.7391990065 4631826.23431028)
# 7140     POINT (444894.8869103333 4648779.807261443)
# 7980     POINT (443028.3288650483 4639191.897460226)
# 1045      POINT (441737.3441270432 4634934.81501118)
# 1065     POINT (436678.9504628467 4637309.836276419)
# 5850      POINT (439721.7617521951 4635259.95751149)
# 1055     POINT (445284.2663228074 4634805.536912974)

# %%
schools_unary_union = schools.unary_union

# %%
crimes_extract['nearest_id'] = crimes_extract.apply(distance_to_nearest,
                                                    geom_union=schools_unary_union,
                                                    df1=crimes_extract,
                                                    df2=schools,
                                                    src_column='UNIT_ID',
                                                    geom1_col='UTMPoint',
                                                    geom2_col='UTMPoint',
                                                    axis=1)
crimes_extract.head()
# Out:
# ID                                                   8265244
# case number                                         HT498458
# date                                  09/15/2011 08:00:00 AM
# block                                     040XX N MENARD AVE
# iucr                                                    0620
# primary type                                        BURGLARY
# desc                                          UNLAWFUL ENTRY
# locdesc                                            RESIDENCE
# arrest                                                  True
# domestic                                               False
# beat                                                    1624
# district                                                  16
# ward                                                      38
# community area                                            15
# fbi code                                                  05
# x coord                                          1.13696e+06
# y coord                                          1.92632e+06
# year                                                    2011
# updated on                            02/12/2018 03:46:59 PM
# lat                                                   41.954
# lon                                                 -87.7719
# location                        (41.95396528, -87.771918163)
# community                                       PORTAGE PARK
# UTMx                                                  436025
# UTMy                                             4.64495e+06
# UTMPoint          POINT (436025.3086861699 4644953.17679981)
# Name: 0, dtype: object
# UNIT_ID
# 4610    False
# 5180    False
# 5300    False
# 5440    False
# 5610    False
# 5670    False
# 5880    False
# 6100    False
# 6350    False
# 6900    False
# 1135    False
# 2123    False
# 2123    False
# 1105    False
# 6320    False
# 6450    False
# 6570    False
# 7190    False
# 7610    False
# 5640    False
# 6490    False
# 4230    False
# 4310    False
# 4430    False
# 4430    False
# 4710    False
# 5430    False
# 5970    False
# 7720    False
# 4330    False
# 6710    False
# 2940    False
# 4650    False
# 5370    False
# 5480    False
# 6750    False
# 6760    False
# 2510    False
# 2590    False
# 2910    False
# 2970    False
# 3260    False
# 3370    False
# 3380    False
# 3520    False
# 3630    False
# 3690    False
# 3760    False
# 3900    False
# 3980    False
# 4250    False
# 4320    False
# 4720    False
# 5390    False
# 6310    False
# 6440    False
# 6930    False
# 7490    False
# 7880    False
# 8021    False
# 2580    False
# 2830    False
# 3040    False
# 3110    False
# 3530    False
# 3720    False
# 4350    False
# 4570    False
# 6880    False
# 6880    False
# 7050    False
# 7080    False
# 7240    False
# 7250    False
# 7260    False
# 7760    False
# 2015    False
# 2680    False
# 3070    False
# 3320    False
# 3360    False
# 3860    False
# 4260    False
# 4390    False
# 4740    False
# 5250    False
# 5580    False
# 5830    False
# 5920    False
# 6300    False
# 6780    False
# 6810    False
# 6891    False
# 6891    False
# 2150    False
# 2280    False
# 2650    False
# 2860    False
# 3160    False
# 3250    False
# 3330    False
# 3400    False
# 3430    False
# 3670    False
# 4090    False
# 4360    False
# 4410    False
# 4830    False
# 4960    False
# 4980    False
# 1106    False
# 1121    False
# 1165    False
# 1720    False
# 1930    False
# 1931    False
# 2350    False
# 2570    False
# 3200    False
# 3890    False
# 4120    False
# 4620    False
# 4660    False
# 4760    False
# 4880    False
# 5090    False
# 5340    False
# 6030    False
# 6220    False
# 6430    False
# 7170    False
# 7870    False
# 2100    False
# 2460    False
# 2670    False
# 3030    False
# 3440    False
# 3550    False
# 3600    False
# 3740    False
# 3920    False
# 3930    False
# 4030    False
# 4470    False
# 5230    False
# 5280    False
# 5650    False
# 5750    False
# 5900    False
# 6540    False
# 6560    False
# 6660    False
# 6950    False
# 6960    False
# 7000    False
# 7820    False
# 4700    False
# 7390    False
# 3130    False
# 3290    False
# 7150    False
# 7830    False
# 2050    False
# 2170    False
# 2180    False
# 2200    False
# 2200    False
# 2330    False
# 2410    False
# 3010    False
# 4270    False
# 5170    False
# 5270    False
# 5270    False
# 5290    False
# 5660    False
# 6390    False
# 6500    False
# 6550    False
# 6870    False
# 7580    False
# 1230    False
# 1320    False
# 1340    False
# 1380    False
# 7370    False
# 7570    False
# 1350    False
# 1630    False
# 1860    False
# 7340    False
# 1150    False
# 1390    False
# 1420    False
# 7220    False
# 7230    False
# 7380    False
# 1010    False
# 1490    False
# 1870    False
# 7360    False
# 7550    False
# 7670    False
# 1145    False
# 2210    False
# 7200    False
# 1540    False
# 6630    False
# 5240    False
# 5420    False
# 6050    False
# 6250    False
# 7100    False
# 7990    False
# 8030    False
# 8060    False
# 8090    False
# 2130    False
# 2340    False
# 2430    False
# 2520    False
# 6970    False
# 7010    False
# 2360    False
# 2390    False
# 2480    False
# 2690    False
# 2710    False
# 2790    False
# 3190    False
# 3470    False
# 3490    False
# 3570    False
# 3870    False
# 4100    False
# 4550    False
# 5040    False
# 5460    False
# 5530    False
# 5740    False
# 5930    False
# 5950    False
# 6150    False
# 6170    False
# 6180    False
# 6260    False
# 6400    False
# 6420    False
# 7210    False
# 7440    False
#         ...
# 2220    False
# 2260    False
# 7600    False
# 7630    False
# 8083    False
# 1430    False
# 1440    False
# 1520    False
# 1740    False
# 2110    False
# 2240    False
# 2380    False
# 2440    False
# 2950    False
# 3280    False
# 3620    False
# 3940    False
# 4180    False
# 4560    False
# 5190    False
# 5200    False
# 5510    False
# 5550    False
# 5690    False
# 5720    False
# 5960    False
# 5980    False
# 6070    False
# 6470    False
# 6990    False
# 1090    False
# 1140    False
# 1620    False
# 3460    False
# 3560    False
# 4840    False
# 5080    False
# 5150    False
# 5150    False
# 6720    False
# 8040    False
# 1060    False
# 1810    False
# 3700    False
# 3880    False
# 4160    False
# 4690    False
# 4920    False
# 5940    False
# 6110    False
# 6330    False
# 1760    False
# 1820    False
# 2540    False
# 2660    False
# 3650    False
# 3820    False
# 5820    False
# 5860    False
# 5910    False
# 6010    False
# 6680    False
# 7470    False
# 7930    False
# 2630    False
# 2980    False
# 3080    False
# 3140    False
# 3640    False
# 3680    False
# 3710    False
# 3780    False
# 5030    False
# 5310    False
# 4670    False
# 5050    False
# 5700    False
# 6000    False
# 6520    False
# 7040    False
# 7320    False
# 8050    False
# 8600    False
# 8023    False
# 2090    False
# 2610    False
# 2760    False
# 2770    False
# 2850    False
# 2960    False
# 3390    False
# 3770    False
# 4290    False
# 4400    False
# 4500    False
# 4540    False
# 4600    False
# 4600    False
# 4770    False
# 4870    False
# 5000    False
# 5100    False
# 5110    False
# 5140    False
# 5210    False
# 5800    False
# 6080    False
# 6280    False
# 6510    False
# 7510    False
# 8035    False
# 2030    False
# 2040    False
# 2060    False
# 2140    False
# 2370    False
# 2620    False
# 2800    False
# 3020    False
# 3150    False
# 3170    False
# 3270    False
# 3510    False
# 3810    False
# 4000    False
# 4010    False
# 4850    False
# 5020    False
# 5120    False
# 5260    False
# 5410    False
# 5490    False
# 5590    False
# 5600    False
# 5730    False
# 6190    False
# 6270    False
# 6290    False
# 7520    False
# 7520    False
# 7890    False
# 8045    False
# 8440    False
# 2080    False
# 2190    False
# 2270    False
# 2300    False
# 2320    False
# 2730    False
# 2750    False
# 2810    False
# 2870    False
# 2880    False
# 2990    False
# 3350    False
# 3480    False
# 3590    False
# 3730    False
# 3850    False
# 4170    False
# 4170    False
# 4300    False
# 4800    False
# 5070    False
# 5360    False
# 5630    False
# 6040    False
# 6060    False
# 6130    False
# 6230    False
# 6370    False
# 6600    False
# 6910    False
# 7060    False
# 7910    False
# 8000    False
# 4890    False
# 2230    False
# 2450    False
# 2550    False
# 3220    False
# 3230    False
# 3840    False
# 4280    False
# 4450    False
# 4510    False
# 4530    False
# 2470    False
# 2530    False
# 2530    False
# 2640    False
# 3120    False
# 3420    False
# 3830    False
# 4200    False
# 4380    False
# 4420    False
# 4480    False
# 4490    False
# 4580    False
# 4680    False
# 5220    False
# 5220    False
# 5330    False
# 5500    False
# 5520    False
# 5520    False
# 5790    False
# 6140    False
# 6460    False
# 6460    False
# 7420    False
# 7560    False
# 7790    False
# 5850    False
# 5470    False
# 5680    False
# 2250    False
# 2400    False
# 2400    False
# 3000    False
# 3240    False
# 3410    False
# 3660    False
# 3910    False
# 3950    False
# 4110    False
# 4640    False
# 5350    False
# 5450    False
# 6210    False
# 6340    False
# 6380    False
# 6590    False
# 6610    False
# 6730    False
# 6740    False
# 6920    False
# 7840    False
# 8024    False
# 2070    False
# 2740    False
# 2890    False
# 2930    False
# 3100    False
# 3750    False
# 3960    False
# 3970    False
# 4020    False
# 4210    False
# Name: UTMPoint, Length: 688, dtype: bool
# ID                                                   8265244
# case number                                         HT498458
# date                                  09/15/2011 08:00:00 AM
# block                                     040XX N MENARD AVE
# iucr                                                    0620
# primary type                                        BURGLARY
# desc                                          UNLAWFUL ENTRY
# locdesc                                            RESIDENCE
# arrest                                                  True
# domestic                                               False
# beat                                                    1624
# district                                                  16
# ward                                                      38
# community area                                            15
# fbi code                                                  05
# x coord                                          1.13696e+06
# y coord                                          1.92632e+06
# year                                                    2011
# updated on                            02/12/2018 03:46:59 PM
# lat                                                   41.954
# lon                                                 -87.7719
# location                        (41.95396528, -87.771918163)
# community                                       PORTAGE PARK
# UTMx                                                  436025
# UTMy                                             4.64495e+06
# UTMPoint          POINT (436025.3086861699 4644953.17679981)
# Name: 0, dtype: object
# UNIT_ID
# 4610    False
# 5180    False
# 5300    False
# 5440    False
# 5610    False
# 5670    False
# 5880    False
# 6100    False
# 6350    False
# 6900    False
# 1135    False
# 2123    False
# 2123    False
# 1105    False
# 6320    False
# 6450    False
# 6570    False
# 7190    False
# 7610    False
# 5640    False
# 6490    False
# 4230    False
# 4310    False
# 4430    False
# 4430    False
# 4710    False
# 5430    False
# 5970    False
# 7720    False
# 4330    False
# 6710    False
# 2940    False
# 4650    False
# 5370    False
# 5480    False
# 6750    False
# 6760    False
# 2510    False
# 2590    False
# 2910    False
# 2970    False
# 3260    False
# 3370    False
# 3380    False
# 3520    False
# 3630    False
# 3690    False
# 3760    False
# 3900    False
# 3980    False
# 4250    False
# 4320    False
# 4720    False
# 5390    False
# 6310    False
# 6440    False
# 6930    False
# 7490    False
# 7880    False
# 8021    False
# 2580    False
# 2830    False
# 3040    False
# 3110    False
# 3530    False
# 3720    False
# 4350    False
# 4570    False
# 6880    False
# 6880    False
# 7050    False
# 7080    False
# 7240    False
# 7250    False
# 7260    False
# 7760    False
# 2015    False
# 2680    False
# 3070    False
# 3320    False
# 3360    False
# 3860    False
# 4260    False
# 4390    False
# 4740    False
# 5250    False
# 5580    False
# 5830    False
# 5920    False
# 6300    False
# 6780    False
# 6810    False
# 6891    False
# 6891    False
# 2150    False
# 2280    False
# 2650    False
# 2860    False
# 3160    False
# 3250    False
# 3330    False
# 3400    False
# 3430    False
# 3670    False
# 4090    False
# 4360    False
# 4410    False
# 4830    False
# 4960    False
# 4980    False
# 1106    False
# 1121    False
# 1165    False
# 1720    False
# 1930    False
# 1931    False
# 2350    False
# 2570    False
# 3200    False
# 3890    False
# 4120    False
# 4620    False
# 4660    False
# 4760    False
# 4880    False
# 5090    False
# 5340    False
# 6030    False
# 6220    False
# 6430    False
# 7170    False
# 7870    False
# 2100    False
# 2460    False
# 2670    False
# 3030    False
# 3440    False
# 3550    False
# 3600    False
# 3740    False
# 3920    False
# 3930    False
# 4030    False
# 4470    False
# 5230    False
# 5280    False
# 5650    False
# 5750    False
# 5900    False
# 6540    False
# 6560    False
# 6660    False
# 6950    False
# 6960    False
# 7000    False
# 7820    False
# 4700    False
# 7390    False
# 3130    False
# 3290    False
# 7150    False
# 7830    False
# 2050    False
# 2170    False
# 2180    False
# 2200    False
# 2200    False
# 2330    False
# 2410    False
# 3010    False
# 4270    False
# 5170    False
# 5270    False
# 5270    False
# 5290    False
# 5660    False
# 6390    False
# 6500    False
# 6550    False
# 6870    False
# 7580    False
# 1230    False
# 1320    False
# 1340    False
# 1380    False
# 7370    False
# 7570    False
# 1350    False
# 1630    False
# 1860    False
# 7340    False
# 1150    False
# 1390    False
# 1420    False
# 7220    False
# 7230    False
# 7380    False
# 1010    False
# 1490    False
# 1870    False
# 7360    False
# 7550    False
# 7670    False
# 1145    False
# 2210    False
# 7200    False
# 1540    False
# 6630    False
# 5240    False
# 5420    False
# 6050    False
# 6250    False
# 7100    False
# 7990    False
# 8030    False
# 8060    False
# 8090    False
# 2130    False
# 2340    False
# 2430    False
# 2520    False
# 6970    False
# 7010    False
# 2360    False
# 2390    False
# 2480    False
# 2690    False
# 2710    False
# 2790    False
# 3190    False
# 3470    False
# 3490    False
# 3570    False
# 3870    False
# 4100    False
# 4550    False
# 5040    False
# 5460    False
# 5530    False
# 5740    False
# 5930    False
# 5950    False
# 6150    False
# 6170    False
# 6180    False
# 6260    False
# 6400    False
# 6420    False
# 7210    False
# 7440    False
#         ...
# 2220    False
# 2260    False
# 7600    False
# 7630    False
# 8083    False
# 1430    False
# 1440    False
# 1520    False
# 1740    False
# 2110    False
# 2240    False
# 2380    False
# 2440    False
# 2950    False
# 3280    False
# 3620    False
# 3940    False
# 4180    False
# 4560    False
# 5190    False
# 5200    False
# 5510    False
# 5550    False
# 5690    False
# 5720    False
# 5960    False
# 5980    False
# 6070    False
# 6470    False
# 6990    False
# 1090    False
# 1140    False
# 1620    False
# 3460    False
# 3560    False
# 4840    False
# 5080    False
# 5150    False
# 5150    False
# 6720    False
# 8040    False
# 1060    False
# 1810    False
# 3700    False
# 3880    False
# 4160    False
# 4690    False
# 4920    False
# 5940    False
# 6110    False
# 6330    False
# 1760    False
# 1820    False
# 2540    False
# 2660    False
# 3650    False
# 3820    False
# 5820    False
# 5860    False
# 5910    False
# 6010    False
# 6680    False
# 7470    False
# 7930    False
# 2630    False
# 2980    False
# 3080    False
# 3140    False
# 3640    False
# 3680    False
# 3710    False
# 3780    False
# 5030    False
# 5310    False
# 4670    False
# 5050    False
# 5700    False
# 6000    False
# 6520    False
# 7040    False
# 7320    False
# 8050    False
# 8600    False
# 8023    False
# 2090    False
# 2610    False
# 2760    False
# 2770    False
# 2850    False
# 2960    False
# 3390    False
# 3770    False
# 4290    False
# 4400    False
# 4500    False
# 4540    False
# 4600    False
# 4600    False
# 4770    False
# 4870    False
# 5000    False
# 5100    False
# 5110    False
# 5140    False
# 5210    False
# 5800    False
# 6080    False
# 6280    False
# 6510    False
# 7510    False
# 8035    False
# 2030    False
# 2040    False
# 2060    False
# 2140    False
# 2370    False
# 2620    False
# 2800    False
# 3020    False
# 3150    False
# 3170    False
# 3270    False
# 3510    False
# 3810    False
# 4000    False
# 4010    False
# 4850    False
# 5020    False
# 5120    False
# 5260    False
# 5410    False
# 5490    False
# 5590    False
# 5600    False
# 5730    False
# 6190    False
# 6270    False
# 6290    False
# 7520    False
# 7520    False
# 7890    False
# 8045    False
# 8440    False
# 2080    False
# 2190    False
# 2270    False
# 2300    False
# 2320    False
# 2730    False
# 2750    False
# 2810    False
# 2870    False
# 2880    False
# 2990    False
# 3350    False
# 3480    False
# 3590    False
# 3730    False
# 3850    False
# 4170    False
# 4170    False
# 4300    False
# 4800    False
# 5070    False
# 5360    False
# 5630    False
# 6040    False
# 6060    False
# 6130    False
# 6230    False
# 6370    False
# 6600    False
# 6910    False
# 7060    False
# 7910    False
# 8000    False
# 4890    False
# 2230    False
# 2450    False
# 2550    False
# 3220    False
# 3230    False
# 3840    False
# 4280    False
# 4450    False
# 4510    False
# 4530    False
# 2470    False
# 2530    False
# 2530    False
# 2640    False
# 3120    False
# 3420    False
# 3830    False
# 4200    False
# 4380    False
# 4420    False
# 4480    False
# 4490    False
# 4580    False
# 4680    False
# 5220    False
# 5220    False
# 5330    False
# 5500    False
# 5520    False
# 5520    False
# 5790    False
# 6140    False
# 6460    False
# 6460    False
# 7420    False
# 7560    False
# 7790    False
# 5850    False
# 5470    False
# 5680    False
# 2250    False
# 2400    False
# 2400    False
# 3000    False
# 3240    False
# 3410    False
# 3660    False
# 3910    False
# 3950    False
# 4110    False
# 4640    False
# 5350    False
# 5450    False
# 6210    False
# 6340    False
# 6380    False
# 6590    False
# 6610    False
# 6730    False
# 6740    False
# 6920    False
# 7840    False
# 8024    False
# 2070    False
# 2740    False
# 2890    False
# 2930    False
# 3100    False
# 3750    False
# 3960    False
# 3970    False
# 4020    False
# 4210    False
# Name: UTMPoint, Length: 688, dtype: bool
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-119-3ff01926f05c> in <module>
#       6                                                     geom1_col='UTMPoint',
#       7                                                     geom2_col='UTMPoint',
# ----> 8                                                     axis=1)
#       9 crimes_extract.head()
#
# ~/anaconda3/envs/geospatial/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# ~/anaconda3/envs/geospatial/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~/anaconda3/envs/geospatial/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     246
#     247         # compute the result using the series generator
# --> 248         self.apply_series_generator()
#     249
#     250         # wrap results
#
# ~/anaconda3/envs/geospatial/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     275             try:
#     276                 for i, v in enumerate(series_gen):
# --> 277                     results[i] = self.f(v)
#     278                     keys.append(v.name)
#     279             except Exception as e:
#
# ~/anaconda3/envs/geospatial/lib/python3.7/site-packages/pandas/core/apply.py in f(x)
#      72         if kwds or args and not isinstance(func, np.ufunc):
#      73             def f(x):
# ---> 74                 return func(x, *args, **kwds)
#      75         else:
#      76             f = func
#
# <ipython-input-118-e6bbbe2914eb> in distance_to_nearest(row, geom_union, df1, df2, geom1_col, geom2_col, src_column)
#       7      print(nearest)
#       8      # Get the corresponding value from df2 (matching is based on the geometry)
# ----> 9      nearest_id = df2[nearest][src_column].get_values()[0]
#      10      start_point: shapely.geometry.Point = row['geometry']
#      11      end_point_series: pd.Series = df2[nearest]['geometry']
#
# IndexError: ('index 0 is out of bounds for axis 0 with size 0', 'occurred at index 0')

# %%
my_nearest_point = schools['UTMPoint'] == nearest_points(crimes.iloc[0]['UTMPoint'], schools_unary_union)[1]
print(my_nearest_point)
schools['UTMPoint' == my_nearest_point]
# Out:
# UNIT_ID
# 4610    False
# 5180    False
# 5300    False
# 5440    False
# 5610    False
# 5670    False
# 5880    False
# 6100    False
# 6350    False
# 6900    False
# 1135    False
# 2123    False
# 2123    False
# 1105    False
# 6320    False
# 6450    False
# 6570    False
# 7190    False
# 7610    False
# 5640    False
# 6490    False
# 4230    False
# 4310    False
# 4430    False
# 4430    False
# 4710    False
# 5430    False
# 5970    False
# 7720    False
# 4330    False
# 6710    False
# 2940    False
# 4650    False
# 5370    False
# 5480    False
# 6750    False
# 6760    False
# 2510    False
# 2590    False
# 2910    False
# 2970    False
# 3260    False
# 3370    False
# 3380    False
# 3520    False
# 3630    False
# 3690    False
# 3760    False
# 3900    False
# 3980    False
# 4250    False
# 4320    False
# 4720    False
# 5390    False
# 6310    False
# 6440    False
# 6930    False
# 7490    False
# 7880    False
# 8021    False
# 2580    False
# 2830    False
# 3040    False
# 3110    False
# 3530    False
# 3720    False
# 4350    False
# 4570    False
# 6880    False
# 6880    False
# 7050    False
# 7080    False
# 7240    False
# 7250    False
# 7260    False
# 7760    False
# 2015    False
# 2680    False
# 3070    False
# 3320    False
# 3360    False
# 3860    False
# 4260    False
# 4390    False
# 4740    False
# 5250    False
# 5580    False
# 5830    False
# 5920    False
# 6300    False
# 6780    False
# 6810    False
# 6891    False
# 6891    False
# 2150    False
# 2280    False
# 2650    False
# 2860    False
# 3160    False
# 3250    False
# 3330    False
# 3400    False
# 3430    False
# 3670    False
# 4090    False
# 4360    False
# 4410    False
# 4830    False
# 4960    False
# 4980    False
# 1106    False
# 1121    False
# 1165    False
# 1720    False
# 1930    False
# 1931    False
# 2350    False
# 2570    False
# 3200    False
# 3890    False
# 4120    False
# 4620    False
# 4660    False
# 4760    False
# 4880    False
# 5090    False
# 5340    False
# 6030    False
# 6220    False
# 6430    False
# 7170    False
# 7870    False
# 2100    False
# 2460    False
# 2670    False
# 3030    False
# 3440    False
# 3550    False
# 3600    False
# 3740    False
# 3920    False
# 3930    False
# 4030    False
# 4470    False
# 5230    False
# 5280    False
# 5650    False
# 5750    False
# 5900    False
# 6540    False
# 6560    False
# 6660    False
# 6950    False
# 6960    False
# 7000    False
# 7820    False
# 4700    False
# 7390    False
# 3130    False
# 3290    False
# 7150    False
# 7830    False
# 2050    False
# 2170    False
# 2180    False
# 2200    False
# 2200    False
# 2330    False
# 2410    False
# 3010    False
# 4270    False
# 5170    False
# 5270    False
# 5270    False
# 5290    False
# 5660    False
# 6390    False
# 6500    False
# 6550    False
# 6870    False
# 7580    False
# 1230    False
# 1320    False
# 1340    False
# 1380    False
# 7370    False
# 7570    False
# 1350    False
# 1630    False
# 1860    False
# 7340    False
# 1150    False
# 1390    False
# 1420    False
# 7220    False
# 7230    False
# 7380    False
# 1010    False
# 1490    False
# 1870    False
# 7360    False
# 7550    False
# 7670    False
# 1145    False
# 2210    False
# 7200    False
# 1540    False
# 6630    False
# 5240    False
# 5420    False
# 6050    False
# 6250    False
# 7100    False
# 7990    False
# 8030    False
# 8060    False
# 8090    False
# 2130    False
# 2340    False
# 2430    False
# 2520    False
# 6970    False
# 7010    False
# 2360    False
# 2390    False
# 2480    False
# 2690    False
# 2710    False
# 2790    False
# 3190    False
# 3470    False
# 3490    False
# 3570    False
# 3870    False
# 4100    False
# 4550    False
# 5040    False
# 5460    False
# 5530    False
# 5740    False
# 5930    False
# 5950    False
# 6150    False
# 6170    False
# 6180    False
# 6260    False
# 6400    False
# 6420    False
# 7210    False
# 7440    False
#         ...
# 2220    False
# 2260    False
# 7600    False
# 7630    False
# 8083    False
# 1430    False
# 1440    False
# 1520    False
# 1740    False
# 2110    False
# 2240    False
# 2380    False
# 2440    False
# 2950    False
# 3280    False
# 3620    False
# 3940    False
# 4180    False
# 4560    False
# 5190    False
# 5200    False
# 5510    False
# 5550    False
# 5690    False
# 5720    False
# 5960    False
# 5980    False
# 6070    False
# 6470    False
# 6990    False
# 1090    False
# 1140    False
# 1620    False
# 3460    False
# 3560    False
# 4840    False
# 5080    False
# 5150    False
# 5150    False
# 6720    False
# 8040    False
# 1060    False
# 1810    False
# 3700    False
# 3880    False
# 4160    False
# 4690    False
# 4920    False
# 5940    False
# 6110    False
# 6330    False
# 1760    False
# 1820    False
# 2540    False
# 2660    False
# 3650    False
# 3820    False
# 5820    False
# 5860    False
# 5910    False
# 6010    False
# 6680    False
# 7470    False
# 7930    False
# 2630    False
# 2980    False
# 3080    False
# 3140    False
# 3640    False
# 3680    False
# 3710    False
# 3780    False
# 5030    False
# 5310    False
# 4670    False
# 5050    False
# 5700    False
# 6000    False
# 6520    False
# 7040    False
# 7320    False
# 8050    False
# 8600    False
# 8023    False
# 2090    False
# 2610    False
# 2760    False
# 2770    False
# 2850    False
# 2960    False
# 3390    False
# 3770    False
# 4290    False
# 4400    False
# 4500    False
# 4540    False
# 4600    False
# 4600    False
# 4770    False
# 4870    False
# 5000    False
# 5100    False
# 5110    False
# 5140    False
# 5210    False
# 5800    False
# 6080    False
# 6280    False
# 6510    False
# 7510    False
# 8035    False
# 2030    False
# 2040    False
# 2060    False
# 2140    False
# 2370    False
# 2620    False
# 2800    False
# 3020    False
# 3150    False
# 3170    False
# 3270    False
# 3510    False
# 3810    False
# 4000    False
# 4010    False
# 4850    False
# 5020    False
# 5120    False
# 5260    False
# 5410    False
# 5490    False
# 5590    False
# 5600    False
# 5730    False
# 6190    False
# 6270    False
# 6290    False
# 7520    False
# 7520    False
# 7890    False
# 8045    False
# 8440    False
# 2080    False
# 2190    False
# 2270    False
# 2300    False
# 2320    False
# 2730    False
# 2750    False
# 2810    False
# 2870    False
# 2880    False
# 2990    False
# 3350    False
# 3480    False
# 3590    False
# 3730    False
# 3850    False
# 4170    False
# 4170    False
# 4300    False
# 4800    False
# 5070    False
# 5360    False
# 5630    False
# 6040    False
# 6060    False
# 6130    False
# 6230    False
# 6370    False
# 6600    False
# 6910    False
# 7060    False
# 7910    False
# 8000    False
# 4890    False
# 2230    False
# 2450    False
# 2550    False
# 3220    False
# 3230    False
# 3840    False
# 4280    False
# 4450    False
# 4510    False
# 4530    False
# 2470    False
# 2530    False
# 2530    False
# 2640    False
# 3120    False
# 3420    False
# 3830    False
# 4200    False
# 4380    False
# 4420    False
# 4480    False
# 4490    False
# 4580    False
# 4680    False
# 5220    False
# 5220    False
# 5330    False
# 5500    False
# 5520    False
# 5520    False
# 5790    False
# 6140    False
# 6460    False
# 6460    False
# 7420    False
# 7560    False
# 7790    False
# 5850    False
# 5470    False
# 5680    False
# 2250    False
# 2400    False
# 2400    False
# 3000    False
# 3240    False
# 3410    False
# 3660    False
# 3910    False
# 3950    False
# 4110    False
# 4640    False
# 5350    False
# 5450    False
# 6210    False
# 6340    False
# 6380    False
# 6590    False
# 6610    False
# 6730    False
# 6740    False
# 6920    False
# 7840    False
# 8024    False
# 2070    False
# 2740    False
# 2890    False
# 2930    False
# 3100    False
# 3750    False
# 3960    False
# 3970    False
# 4020    False
# 4210    False
# Name: UTMPoint, Length: 688, dtype: bool
# /Users/jon/anaconda3/envs/geospatial/lib/python3.7/site-packages/pandas/core/ops.py:1167: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-11476f98aed3> in <module>
#       1 my_nearest_point = schools['UTMPoint'] == nearest_points(crimes.iloc[0]['UTMPoint'], schools_unary_union)[1]
#       2 print(my_nearest_point)
# ----> 3 schools['UTMPoint' == my_nearest_point]
#
# ~/anaconda3/envs/geospatial/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# ~/anaconda3/envs/geospatial/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1167                     result = method(y)
#    1168                 if result is NotImplemented:
# -> 1169                     raise TypeError("invalid type comparison")
#    1170             else:
#    1171                 result = op(x, y)
#
# TypeError: invalid type comparison

# %%
crimes.to_pickle('crimes-transformed.pkl')
