# %% [markdown]
# The data files are zipped in the file datafiles.zip. Where the data is used below, references are made to the origin of that dataset, as well as any modifications that have been done locally.

# %% [markdown]
# Manage imported libraries

# %%
import csv
from os import listdir
from os.path import isfile, join
import geopandas as gpd
import pandas as pd
import shapely
import matplotlib.pylab as pylab
from matplotlib.pyplot import figure
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from scipy import ndimage

pylab.rcParams['figure.figsize'] = 8, 6

# %% [markdown]
# Read in geojson data to geopandas dataframes

# %%
census_income_data = gpd.read_file('census-tracts-2000.geojson')
neighborhoods = gpd.read_file('community-areas.geojson')

# %% [markdown]
# For sanity, display headers for the GPD dataframes

# %%
print(census_income_data.head())

# %%
print(neighborhoods.head())
# Out:
#          community area     shape_area perimeter area_num_1 area_numbe  \
# 0          DOUGLAS    0  46004621.1581         0         35         35
# 1          OAKLAND    0  16913961.0408         0         36         36
# 2      FULLER PARK    0  19916704.8692         0         37         37
# 3  GRAND BOULEVARD    0  48492503.1554         0         38         38
# 4          KENWOOD    0  29071741.9283         0         39         39
#
#   comarea_id comarea      shape_len  \
# 0          0       0  31027.0545098
# 1          0       0  19565.5061533
# 2          0       0  25339.0897503
# 3          0       0  28196.8371573
# 4          0       0  23325.1679062
#
#                                             geometry
# 0  (POLYGON ((-87.60914087617894 41.8446925026539...
# 1  (POLYGON ((-87.59215283879394 41.8169293462668...
# 2  (POLYGON ((-87.62879823733725 41.8018930336891...
# 3  (POLYGON ((-87.6067081256125 41.81681377057218...
# 4  (POLYGON ((-87.59215283879394 41.8169293462668...

# %% [markdown]
# Read in the 2000 median household income data and prepare it for conversion to pandas dataframe. While other data is from either 2010, the most recently-provided MHI data is from 2000, hence the discrepency.
#
# Household income data was derived from a PDF file from the City of Chicago (https://www.chicago.gov/content/dam/city/depts/doit/general/GIS/Chicago_Maps/Census_Maps/Income_MedianHousehold.pdf, a copy included in the github repo), colors read in via Gimp, and manually mapped to census blocks defined in a shapefile (https://data.cityofchicago.org/Facilities-Geographic-Boundaries/Boundaries-Census-Tracts-2000/pt6c-hxpp), also from the City of Chicago.

# %%
with open("sorted-census-tract-median-household-income.csv", "r") as tract_income:
    tract_income_list = list(csv.DictReader(tract_income))

# %% [markdown]
# Convert the household income data into a pandas dataframe and merge it into the tract GPD dataframe

# %%
tract_info_df = pd.DataFrame(tract_income_list)
with_incomes = pd.merge(census_income_data, tract_info_df, on="census_tra")

# %%
print(with_incomes.head())
# Out:
#   tract_cens tract_fips     shape_area perimeter        tract_cent  \
# 0       2000      17031  11228197.5722       0.0  1160171.70454335
# 1       2000      17031  20199335.5566       0.0  1169816.30242459
# 2       2000      17031  3170252.61205       0.0   1166814.1830406
# 3       2000      17031  9690785.77117       0.0  1157599.24855614
# 4       2000      17031  8038189.85397       0.0  1165053.80574048
#
#     census_t_1 tract_numa tract_comm objectid tract_cr_1 data_admin  \
# 0  17031720500         36         72        1       None        0.0
# 1  17031730200        113         73        2       None        0.0
# 2  17031730300         22         73        3       None        0.0
# 3  17031740100         45         74        4       None        0.0
# 4  17031710500         33         71        5       None        0.0
#
#          tract_ce_1 census_tra   tract_ce_3 tract_crea    tract_ce_2  \
# 0   1834962.2944345     720500  41.70283387             -87.68910702
# 1  1843710.10211415     730200  41.72663578             -87.65353787
# 2  1843978.09707551     730300  41.72743573             -87.66452735
# 3  1832915.38233703     740100  41.69726919             -87.69858205
# 4  1851288.62298081     710500  41.74753426             -87.67076974
#
#        shape_len                                           geometry  \
# 0  14047.0507089  (POLYGON ((-87.69148523416723 41.7063622944737...
# 1   19738.525071  (POLYGON ((-87.64651275537268 41.7325265907278...
# 2  9848.21406776  (POLYGON ((-87.66332792156787 41.7212030772242...
# 3  18058.3722532  (POLYGON ((-87.69645961375069 41.7071449131191...
# 4  12094.2889266  (POLYGON ((-87.66338805460082 41.7484781942969...
#
#   income_range
# 0            4
# 1            3
# 2            2
# 3            2
# 4            2

# %% [markdown]
# Plot the city map, colorized by income range, and overlay with the outlines of named neighborhoods (https://data.cityofchicago.org/Facilities-Geographic-Boundaries/Boundaries-Neighborhoods/bbvz-uum9).
#
# Read in crime data (https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2), filtered to just crimes in 2010-2011.
#
# I'm not really happy with how I've read in the crimes dataset, but so far, it's the only way I've figured out to get the GPS coordinates properly added to be used farther down when the data is in the geopandas DataFrame.

# %%
ids = []
date = []
ptype = []
desc = []
locdesc = []
arrest = []
community_area = []
geometry = []

# Read in the two chunks of the CPD crimes dataset, which was broken up
# to fit into the GitHub 100MB/file limit
chunkfiles: list = ['crimes-2010-2011-0.csv', 'crimes-2010-2011-1.csv']

for chunk in chunkfiles:
    with open(chunk, "r") as crimes_fh:
        for row in crimes_fh:
            if "IUCR" in row or '"(41' not in row:
                # Ignore the header row and rows missing GPS coordinates
                continue
            else:
                row = row.replace(',,',',<empty>,').replace(')"','').rstrip()
                row = row.lstrip('"(')
                fields = row.split(',')
                ids.append(fields[0])
                date.append(fields[2].split(' ')[0])
                ptype.append(fields[5])
                desc.append(fields[6])
                locdesc.append(fields[7])
                arrest.append(fields[8])
                community_area.append(fields[9])
                lat = float(fields[-3].lstrip('"('))
                lon = float(fields[-4].rstrip(')"'))
                geometry.append(shapely.geometry.point.Point(lat, lon))

# %%
data = {
'date': pd.Series(date, index=ids),
"primary type": pd.Series(ptype, index=ids),
"description": pd.Series(desc, index=ids),
"location description": pd.Series(locdesc, index=ids),
"arrest": pd.Series(arrest, index=ids),
"community area": pd.Series(community_area, index=ids),
"geometry": pd.Series(geometry, index=ids)   
     }

# %%
crimes = gpd.GeoDataFrame(data, index=ids)

# %% [markdown]
# These are the absolute bounds of the crimes dataset's GPS coordinates

# %%
crimes_minx = crimes['geometry'].bounds['minx'].min()
crimes_miny = crimes['geometry'].bounds['miny'].min()
crimes_maxx = crimes['geometry'].bounds['maxx'].min()
crimes_maxy = crimes['geometry'].bounds['maxy'].min()

# %%
print(crimes_minx)
print(crimes_miny)
print(crimes_maxx)
print(crimes_maxy)
print(crimes.head)
# Out:
# -87.927881741
# 41.644589713
# -87.927881741
# 41.644589713
# <bound method NDFrame.head of                 date                primary type  \
# 8265244   09/15/2011                    BURGLARY
# 5147738   08/01/2001  OFFENSE INVOLVING CHILDREN
# 5281401   02/26/2001               OTHER OFFENSE
# 5622147   12/01/2001  OFFENSE INVOLVING CHILDREN
# 11020229  01/01/2010         CRIM SEXUAL ASSAULT
# 5746138   01/01/2001  OFFENSE INVOLVING CHILDREN
# 5868895   10/25/2001                 SEX OFFENSE
# 5969635   09/01/2001         CRIM SEXUAL ASSAULT
# 8187948   07/28/2011                    BURGLARY
# 8263618   09/13/2011                    BURGLARY
# 10316093  08/15/2010         CRIM SEXUAL ASSAULT
# 6283994   04/01/2001                       THEFT
# 6931740   11/07/2001         CRIM SEXUAL ASSAULT
# 6959542   05/26/2001         CRIM SEXUAL ASSAULT
# 7158688   01/01/2001          DECEPTIVE PRACTICE
# 7236800   04/01/2001  OFFENSE INVOLVING CHILDREN
# 7277327   01/01/2001                       THEFT
# 7331615   01/01/2001                       THEFT
# 7333032   01/01/2001  OFFENSE INVOLVING CHILDREN
# 7357666   10/05/2001         CRIM SEXUAL ASSAULT
# 7357772   07/01/2001                       THEFT
# 7362427   09/01/2001                       THEFT
# 7365413   06/01/2001         CRIM SEXUAL ASSAULT
# 7386226   06/01/2001  OFFENSE INVOLVING CHILDREN
# 7386227   06/01/2001  OFFENSE INVOLVING CHILDREN
# 7425927   02/05/2001                 SEX OFFENSE
# 7451005   12/19/2001  OFFENSE INVOLVING CHILDREN
# 7451703   01/01/2001  OFFENSE INVOLVING CHILDREN
# 7451730   01/01/2001  OFFENSE INVOLVING CHILDREN
# 7452998   06/01/2001                 SEX OFFENSE
# ...              ...                         ...
# 7654718   08/07/2010                       THEFT
# 7669578   08/21/2010                       THEFT
# 7679993   08/27/2010                       THEFT
# 7694794   09/06/2010                       THEFT
# 7726933   09/26/2010                       THEFT
# 8167040   06/22/2011                       THEFT
# 24284     08/24/2011                    HOMICIDE
# 7739356   10/04/2010                       THEFT
# 8011664   04/02/2011               OTHER OFFENSE
# 8051458   04/09/2011               OTHER OFFENSE
# 7688281   09/01/2010                       THEFT
# 7743816   10/06/2010                     ROBBERY
# 7744870   10/07/2010                       THEFT
# 7762177   10/18/2010                       THEFT
# 7793220   10/29/2010                       THEFT
# 7810751   11/17/2010                       THEFT
# 8317209   10/19/2011                       THEFT
# 11505430  05/20/2011         CRIM SEXUAL ASSAULT
# 8206161   08/09/2011                       THEFT
# 8233358   08/26/2011                       THEFT
# 8237856   08/29/2011                       THEFT
# 8294719   10/05/2011                       THEFT
# 8348203   11/09/2011                       THEFT
# 7968263   03/12/2011                       THEFT
# 7517067   05/22/2010                    BURGLARY
# 7626966   07/27/2010                     ROBBERY
# 7545290   06/08/2010                     ROBBERY
# 7556635   06/15/2010                     ROBBERY
# 8131856   06/26/2011                     ROBBERY
# 8198043   07/12/2011                     ROBBERY
#
#                              description          location description arrest  \
# 8265244                   UNLAWFUL ENTRY                     RESIDENCE   true
# 5147738   AGG SEX ASSLT OF CHILD FAM MBR                     RESIDENCE   true
# 5281401       OTHER CRIME AGAINST PERSON     HOSPITAL BUILDING/GROUNDS  false
# 5622147    SEX ASSLT OF CHILD BY FAM MBR                     RESIDENCE  false
# 11020229                       PREDATORY                     RESIDENCE   true
# 5746138     CRIM SEX ABUSE BY FAM MEMBER                     RESIDENCE   true
# 5868895    ATT AGG CRIMINAL SEXUAL ABUSE                     RESIDENCE  false
# 5969635                        PREDATORY                     RESIDENCE   true
# 8187948                   FORCIBLE ENTRY                     APARTMENT   true
# 8263618                    HOME INVASION                     APARTMENT  false
# 10316093                       PREDATORY                     RESIDENCE   true
# 6283994    FINANCIAL ID THEFT: OVER $300                     RESIDENCE  false
# 6931740                        PREDATORY                     APARTMENT   true
# 6959542                AGGRAVATED: OTHER                     RESIDENCE  false
# 7158688                     EMBEZZLEMENT  COMMERCIAL / BUSINESS OFFICE   true
# 7236800   AGG SEX ASSLT OF CHILD FAM MBR                     RESIDENCE  false
# 7277327   FINANCIAL ID THEFT:$300 &UNDER                     RESIDENCE  false
# 7331615    FINANCIAL ID THEFT: OVER $300                     RESIDENCE  false
# 7333032   AGG SEX ASSLT OF CHILD FAM MBR                     RESIDENCE  false
# 7357666                AGGRAVATED: OTHER                     RESIDENCE  false
# 7357772    FINANCIAL ID THEFT: OVER $300                     RESIDENCE  false
# 7362427    FINANCIAL ID THEFT: OVER $300                     APARTMENT  false
# 7365413              AGGRAVATED: HANDGUN                     RESIDENCE  false
# 7386226   AGG SEX ASSLT OF CHILD FAM MBR                     RESIDENCE  false
# 7386227    AGG CRIM SEX ABUSE FAM MEMBER                     RESIDENCE  false
# 7425927      INDECENT SOLICITATION/CHILD                     RESIDENCE  false
# 7451005    AGG CRIM SEX ABUSE FAM MEMBER                     RESIDENCE  false
# 7451703    AGG CRIM SEX ABUSE FAM MEMBER                     RESIDENCE  false
# 7451730    AGG CRIM SEX ABUSE FAM MEMBER                     RESIDENCE  false
# 7452998            CRIMINAL SEXUAL ABUSE                     APARTMENT  false
# ...                                  ...                           ...    ...
# 7654718                     RETAIL THEFT              DEPARTMENT STORE   true
# 7669578                     RETAIL THEFT              DEPARTMENT STORE   true
# 7679993                     RETAIL THEFT            SMALL RETAIL STORE   true
# 7694794                     RETAIL THEFT            GROCERY FOOD STORE   true
# 7726933                   $500 AND UNDER                   GAS STATION   true
# 8167040                   $500 AND UNDER                     RESIDENCE   true
# 24284                FIRST DEGREE MURDER                     APARTMENT  false
# 7739356                        OVER $500                        STREET  false
# 8011664      VIOLATE ORDER OF PROTECTION                     RESIDENCE  false
# 8051458      VIOLATE ORDER OF PROTECTION                         OTHER  false
# 7688281                     RETAIL THEFT            GROCERY FOOD STORE   true
# 7743816   AGGRAVATED VEHICULAR HIJACKING                        STREET   true
# 7744870                     RETAIL THEFT              DEPARTMENT STORE   true
# 7762177                    FROM BUILDING    COLLEGE/UNIVERSITY GROUNDS   true
# 7793220                     RETAIL THEFT              DEPARTMENT STORE   true
# 7810751                   $500 AND UNDER                        STREET   true
# 8317209                        OVER $500                        STREET  false
# 11505430                       PREDATORY                     RESIDENCE   true
# 8206161                     RETAIL THEFT             CONVENIENCE STORE   true
# 8233358                   $500 AND UNDER                      SIDEWALK   true
# 8237856                     RETAIL THEFT            SMALL RETAIL STORE   true
# 8294719                        OVER $500            SMALL RETAIL STORE   true
# 8348203                    FROM BUILDING                     RESIDENCE   true
# 7968263                     RETAIL THEFT            GROCERY FOOD STORE   true
# 7517067                   FORCIBLE ENTRY            SMALL RETAIL STORE  false
# 7626966            STRONGARM - NO WEAPON                        STREET   true
# 7545290   ARMED:KNIFE/CUTTING INSTRUMENT                         ALLEY  false
# 7556635   AGGRAVATED VEHICULAR HIJACKING                        STREET  false
# 8131856    ARMED: OTHER DANGEROUS WEAPON       RESIDENCE PORCH/HALLWAY  false
# 8198043            STRONGARM - NO WEAPON                      SIDEWALK  false
#
#          community area                                 geometry
# 8265244           false        POINT (-87.771918163 41.95396528)
# 5147738           false  POINT (-87.66343916300001 41.802219519)
# 5281401           false  POINT (-87.61391851099999 41.802238398)
# 5622147            true       POINT (-87.719768573 41.931044901)
# 11020229           true  POINT (-87.53045167499999 41.701867053)
# 5746138            true       POINT (-87.709501406 41.863025734)
# 5868895            true       POINT (-87.668546251 41.859146112)
# 5969635           false       POINT (-87.657967351 41.966427663)
# 8187948           false       POINT (-87.651116501 41.945448846)
# 8263618           false       POINT (-87.663352636 41.892477744)
# 10316093           true       POINT (-87.720453904 41.960027497)
# 6283994           false  POINT (-87.73096752399999 41.793240933)
# 6931740           false       POINT (-87.650775702 41.859124203)
# 6959542           false  POINT (-87.64801505699999 41.769669091)
# 7158688           false       POINT (-87.740033361 41.960698401)
# 7236800           false  POINT (-87.70823399699999 41.778997352)
# 7277327           false       POINT (-87.700116823 41.848635623)
# 7331615           false  POINT (-87.61950070499999 41.700687359)
# 7333032           false       POINT (-87.739527446 41.772486481)
# 7357666           false       POINT (-87.716443166 41.894748327)
# 7357772           false         POINT (-87.767545572 41.9441497)
# 7362427           false       POINT (-87.713484317 41.891930523)
# 7365413           false        POINT (-87.743986642 41.87035666)
# 7386226           false       POINT (-87.723975551 41.959705961)
# 7386227           false       POINT (-87.723975551 41.959705961)
# 7425927           false        POINT (-87.742572954 41.92616726)
# 7451005            true       POINT (-87.725809735 41.928393172)
# 7451703           false       POINT (-87.694491418 41.822690348)
# 7451730           false       POINT (-87.674457074 41.805052223)
# 7452998           false       POINT (-87.668971537 41.827979237)
# ...                 ...                                      ...
# 7654718           false        POINT (-87.62418056 41.900266664)
# 7669578           false       POINT (-87.624095634 41.897982937)
# 7679993           false  POINT (-87.62409724299999 41.897837503)
# 7694794           false       POINT (-87.647070253 41.902507824)
# 7726933           false       POINT (-87.637698101 41.896543094)
# 8167040           false       POINT (-87.629946882 41.902670403)
# 24284             false       POINT (-87.661331831 41.812248529)
# 7739356           false       POINT (-87.639828326 41.911830375)
# 8011664           false       POINT (-87.719645597 41.932372448)
# 8051458            true       POINT (-87.719645597 41.932372448)
# 7688281           false  POINT (-87.62091741499999 41.891791478)
# 7743816           false  POINT (-87.63501141899999 41.912879663)
# 7744870           false  POINT (-87.62419389599999 41.892753031)
# 7762177           false       POINT (-87.654782621 41.924175435)
# 7793220           false  POINT (-87.62409660500001 41.897895128)
# 7810751           false  POINT (-87.63730112899999 41.899951772)
# 8317209           false       POINT (-87.747732466 41.873078911)
# 11505430           true        POINT (-87.70603292 41.794550978)
# 8206161           false       POINT (-87.627998797 41.889760548)
# 8233358           false        POINT (-87.626445858 41.89670215)
# 8237856           false  POINT (-87.62416442599999 41.892096977)
# 8294719           false       POINT (-87.624279065 41.896343018)
# 8348203           false       POINT (-87.638427474 41.905833996)
# 7968263           false       POINT (-87.652509775 41.925394137)
# 7517067           false       POINT (-87.711227228 41.778840709)
# 7626966           false       POINT (-87.683180808 41.762419957)
# 7545290           false       POINT (-87.704130179 41.773494589)
# 7556635           false  POINT (-87.74308751300001 41.804818878)
# 8131856           false  POINT (-87.70501421199999 41.843635028)
# 8198043            true       POINT (-87.687142028 41.773117631)
#
# [707052 rows x 7 columns]>

# %% [markdown]
# And these are the absolute bounds of the Chicago map, based on the community_names dataset

# %%
neighborhoods_minx = neighborhoods.bounds['minx'].min()
neighborhoods_miny = neighborhoods.bounds['miny'].min()
neighborhoods_maxx = neighborhoods.bounds['maxx'].min()
neighborhoods_maxy = neighborhoods.bounds['maxy'].min()

# %%
print(neighborhoods_minx)
print(neighborhoods_miny)
print(neighborhoods_maxx)
print(neighborhoods_maxy)
# Out:
# -87.9401140825235
# 41.644543121506054
# -87.83479485589937
# 41.685433883167434

# %% [markdown]
# Generate the first map, showing the median household income data by census tract, overlayed with the borders of the named Chicago neighborhoods.
#
# My intent is to eventually overlay this map with the crimes data, but that's not working yet.

# %%
fig, ax = plt.subplots()
fig.suptitle('Map showing media household income')
ax.set_aspect('equal')
fig.set_size_inches(10,10)
with_incomes.plot(ax=ax, column="income_range",  cmap='PiYG')
neighborhoods.plot(ax=ax, edgecolor='black', color='none')
plt.show()

# %%
def getx(pt):
    return pt.coords[0][0]

def gety(pt):
    return pt.coords[0][1]

# %%
logheatmap = np.log(heatmap)
logheatmap[np.isneginf(logheatmap)] = 0
logheatmap = ndimage.filters.gaussian_filter(logheatmap, 1.3, mode='nearest')
# Out:
# /Users/jon/anaconda3/envs/geospatial/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
matplotlib.colors.BoundaryNorm(np.linspace(1, 5, 5), 5)

# %%
#mapColors = ax.pcolor(with_incomes['income_range'], cmap=cMap)
#mapColors = with_incomes.plot(ax=ax, column="income_range", cmap=cMap)
#cbar = plt.colorbar(mapColors,
#                    ticks=[0, 1, 2, 3, 4, 5],
#                    orientation="horizontal")

#cbar.ax.get_yaxis().set_ticks([])
#for j, lab in enumerate(income_ranges):
#    cbar.ax.text(.5, (2 * j + 1) / 8.0, lab, ha='center', va='center')
#cbar.ax.get_yaxis().labelpad = 15
#cbar.ax.set_ylabel('Income Range', rotation=270)
#cbar.ax.set_xticklabels(income_ranges)

# put the major ticks at the middle of each cell
#ax.set_xticks(np.arange(data.shape[1]) + 0.5, minor=False)
#ax.set_yticks(np.arange(data.shape[0]) + 0.5, minor=False)
#ax.invert_yaxis()

#labels
#column_labels = list('ABCD')
#row_labels = list('WXYZ')
#ax.set_xticklabels(column_labels, minor=False)
#ax.set_yticklabels(row_labels, minor=False)

#cmap = plt.get_cmap('PiYG')
#levels = [0, 1, 2, 3, 4, 5]

# %%
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(20, 10))
#fig.set_size_inches(20,10)

income_ranges = np.array(["",
                          "$0      - $20,000",
                          "$20,001 - $40,000",
                          "$40,001 - $60,000",
                          "$60,001 - $80,000",
                          "$80,001 +"
                         ])

ax.set_aspect('equal')
ax.set_title('Median Household Income by Census Tract - 2000')
ax.axis("off")

cMap = ListedColormap(['white', 'green', 'blue','red', 'black'])

norm = matplotlib.colors.BoundaryNorm(levels, ncolors=cmap.N, clip=True)
fmt = matplotlib.ticker.FuncFormatter(lambda x, pos: qrates[::-1][norm(x)])

#sm = plt.cm.ScalarMappable(cmap = 'PiYG', norm=norm)
#sm._A = []

with_incomes.plot(ax=ax, column="income_range",  cmap='PiYG', legend=True)
neighborhoods.plot(ax=ax, edgecolor='black', color='none')
cb1 = matplotlib.colorbar.ColorbarBase(cmap=cMap,
                                       norm=norm, #Normalize(vmin=1,vmax=5),
                                       orientation='horizontal', ax=ax)
cb1.set_label(income_ranges, fontsize=6)
plt.tight_layout()
#plt.colorbar(ax=ax, format=fmt)

# add the colorbar to the figure
#cbar = fig.colorbar(sm, ax=ax)

ax2.set_aspect('equal')
ax2.set_title('Heatmap of Police Reports - 2010 through 2011')
plt.imshow(logheatmap, cmap="PiYG", extent=extent)
plt.gca().invert_yaxis()
neighborhoods.plot(ax=ax2, edgecolor='black', color='none')
plt.show()

# %% [markdown]
# Below this point are cells I used for testing to understand better how the various bits fit together

# %% [markdown]
# world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# world['centroid_column'] = world.centroid
# print(world.head())
# type(world.iloc[0]['centroid_column'])
